# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("roulette_100000_rounds.csv")
df.head(100)
# Out:
#     Round  Winning Number Winning Color  Red Bet Win  Black Bet Win  \
# 0       1              22         Black            0              1
# 1       2               8         Black            0              1
# 2       3              33         Black            0              1
# 3       4               2         Black            0              1
# 4       5              24         Black            0              1
# ..    ...             ...           ...          ...            ...
# 95     96              22         Black            0              1
# 96     97              34           Red            1              0
# 97     98              22         Black            0              1
# 98     99              14           Red            1              0
# 99    100              19           Red            1              0
#
#     Even Bet Win  Odd Bet Win  Zero Bet Win
# 0              1            0             0
# 1              1            0             0
# ...
